# %%
import numpy as np
import pandas as pd
import re
import time

# %%
from urllib.request import urlopen
from urllib.parse import quote

# %%
from bs4 import BeautifulSoup
from selenium import webdriver

# %% [markdown]
# ### 간편식사

# %%
driver=webdriver.Chrome('C:/scrap/chromedriver.exe')
driver.implicitly_wait(10)
url='http://cu.bgfretail.com/product/product.do?category=product&depth2=4&depth3=1'
driver.get(url)

# %%
SCROLL_PAUSE_TIME = 1
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    try:
        driver.find_element_by_css_selector('#dataTable > div.prodListBtn > div.prodListBtn-w > a').click()
    except: pass
    
    for i in range(5):
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(SCROLL_PAUSE_TIME)
    
    new_height = driver.execute_script("return document.body.scrollHeight")

    if new_height == last_height:
        break
    
    last_height = new_height

# %%
html=driver.page_source
soup=BeautifulSoup(html,'html.parser')

# %%
prodName1=soup.find_all(class_=re.compile('prodName'))[2:]

# %%
name_list1=[]
for name in prodName1:
    name_list1.append(name.string)

# %%
prodPrice1=soup.find_all(class_=re.compile('prodPrice'))[2:]

# %%
price_list1=[]
for price in prodPrice1:
    price_list1.append(price.text[:-1])

# %%
df1=pd.DataFrame({'name':name_list1,'price':price_list1,'category':'instant'})

# %% [markdown]
# ### 과자

# %%
driver=webdriver.Chrome('C:/scrap/chromedriver.exe')
driver.implicitly_wait(10)
url='http://cu.bgfretail.com/product/product.do?category=product&depth2=4&depth3=3'
driver.get(url)

# %%
SCROLL_PAUSE_TIME = 1
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    try:
        driver.find_element_by_css_selector('#dataTable > div.prodListBtn > div.prodListBtn-w > a').click()
    except: pass
    
    for i in range(5):
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(SCROLL_PAUSE_TIME)
    
    new_height = driver.execute_script("return document.body.scrollHeight")

    if new_height == last_height:
        break
    
    last_height = new_height

# %%
html=driver.page_source
soup=BeautifulSoup(html,'html.parser')

# %%
prodName2=soup.find_all(class_=re.compile('prodName'))[2:]

# %%
name_list2=[]
for name in prodName2:
    name_list2.append(name.string)

# %%
prodPrice2=soup.find_all(class_=re.compile('prodPrice'))[2:]

# %%
price_list2=[]
for price in prodPrice2:
    price_list2.append(price.text[:-1])

# %%
df2=pd.DataFrame({'name':name_list2,'price':price_list2,'category':'snack'})

# %% [markdown]
# ### 식품

# %%
driver=webdriver.Chrome('C:/scrap/chromedriver.exe')
driver.implicitly_wait(10)
url='http://cu.bgfretail.com/product/product.do?category=product&depth2=4&depth3=5'
driver.get(url)

# %%
SCROLL_PAUSE_TIME = 1
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    try:
        driver.find_element_by_css_selector('#dataTable > div.prodListBtn > div.prodListBtn-w > a').click()
    except: pass
    
    for i in range(6):
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(SCROLL_PAUSE_TIME)
            
    new_height = driver.execute_script("return document.body.scrollHeight")

    if new_height == last_height:
        break
    
    last_height = new_height

# %%
html=driver.page_source
soup=BeautifulSoup(html,'html.parser')

# %%
prodName3=soup.find_all(class_=re.compile('prodName'))[2:]

# %%
name_list3=[]
for name in prodName3:
    name_list3.append(name.string)

# %%
prodPrice3=soup.find_all(class_=re.compile('prodPrice'))[2:]

# %%
price_list3=[]
for price in prodPrice3:
    price_list3.append(price.text[:-1])

# %%
df3=pd.DataFrame({'name':name_list3,'price':price_list3,'category':'food'})

# %% [markdown]
# ### 음료

# %%
driver=webdriver.Chrome('C:/scrap/chromedriver.exe')
driver.implicitly_wait(10)
url='http://cu.bgfretail.com/product/product.do?category=product&depth2=4&depth3=6'
driver.get(url)

# %%
SCROLL_PAUSE_TIME = 1
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    try:
        driver.find_element_by_css_selector('#dataTable > div.prodListBtn > div.prodListBtn-w > a').click()
    except: pass
    
    for i in range(6):
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(SCROLL_PAUSE_TIME)
            
    new_height = driver.execute_script("return document.body.scrollHeight")

    if new_height == last_height:
        break
    
    last_height = new_height

# %%
html=driver.page_source
soup=BeautifulSoup(html,'html.parser')

# %%
# prodPhoto1=soup.find_all(class_=re.compile('photo'))[2:]

# %%
# img_list1=[]
# for img in prodPhoto1:
#     img_list1.append(img.find('img')['src'])

# %%
# n=10000
# cnt=1
# for image in img_list1:
#     imgUrl = image
#     try:
#         with urlopen(imgUrl) as f:
#             with open('./prod_img/img' + str(n)+'.jpg','wb') as h: # w - write b - binary
#                 img=f.read()
#                 h.write(img)
#     except: pass
    
#     n+=1
#     cnt+=1
    
#     if cnt > len(img_list1):
#         break

# %%
# value = "웅진)하늘보리P340ml.jpg"
# encode = quote(value)
# url = "http://bgf-cu.xcache.kinxcdn.com/product/8801382129608_"+encode

# %%
# with open('./prod_img/img' + str(700)+'.jpg','wb') as h:
#     h.write(urlopen(url).read())

# with open('./prod_img/img' + str(701)+'.jpg','wb') as h:
#     h.write(urlopen(img_list[-1]).read())

# %%
prodName4=soup.find_all(class_=re.compile('prodName'))[2:]

# %%
name_list4=[]
for name in prodName4:
    name_list4.append(name.string)

# %%
prodPrice4=soup.find_all(class_=re.compile('prodPrice'))[2:]

# %%
price_list4=[]
for price in prodPrice4:
    price_list4.append(price.text[:-1])

# %%
df4=pd.DataFrame({'name':name_list4,'price':price_list4,'category':'drink'})
# Out:
#                 name  price category
# 0         마시는식사비건그레인  2,200    drink
# 1           동아)모닝케어D  5,000    drink
# 2     HEYROO미네랄워터P1L    900    drink
# 3            파워마운틴대P  2,900    drink
# 4    서울)스페셜티마일드250ml  1,900    drink
# ..               ...    ...      ...
# 696             솔의눈캔  1,200    drink
# 697   동서)티오피아메리카노275  2,200    drink
# 698     롯데)칸타타아메리카노캔  1,300    drink
# 699    웅진)하늘보리P340ml  1,000    drink
# 700   가야)알로에농장P340ml  1,000    drink
#
# [701 rows x 3 columns]

# %% [markdown]
# ## concat

# %%
df=pd.concat([df1,df2,df3,df4])
df['qty']=100
df=df[['name','price','qty','category']]
df.index=np.array(range(10864,10864+len(df)))
df.index.name='id_key'

df.name=df.name.str.replace(')','_').str.replace('(','_')
df.price=df.price.str.replace(',','').astype('int')

# %%
df
# Out:
#                  name  price  qty category
# 10864       샌_점보4단햄치킨   2500  100  instant
# 10865      햄_크림치즈치킨버거   3300  100  instant
# 10866        햄_빽햄롱롱버거   2900  100  instant
# 10867      주_빽햄데리마요밥바   1900  100  instant
# 10868    주_2XL콘햄김치볶음밥   1400  100  instant
# ...               ...    ...  ...      ...
# 13980            솔의눈캔   1200  100    drink
# 13981  동서_티오피아메리카노275   2200  100    drink
# 13982    롯데_칸타타아메리카노캔   1300  100    drink
# 13983   웅진_하늘보리P340ml   1000  100    drink
# 13984  가야_알로에농장P340ml   1000  100    drink
#
# [3121 rows x 4 columns]

# %%
df.to_csv('prod_info_data.csv')

# %% [markdown]
# ## DB 삽입

# %%
import pymysql
import pyodbc

# %%
mydb = pymysql.connect(
    host = "",
    user = "",
    passwd = "",
    db = "",
    charset=''
)
cursor = mydb.cursor(pymysql.cursors.DictCursor)

# %%
for i in range(len(df)):
    sql = 'INSERT INTO Item_info (Product_name, Price, Qty, Category) VALUES ('+ '"'+ df.name[i]+'"' + ',' + str(df.price[i]) + ',' + str(df.qty[i]) + ',' +'"'+df.category[i]+'"' +');'    
    print(sql)    
    cursor.execute(sql)
# Out:
# INSERT INTO Item_info (Product_name, Price, Qty, Category) VALUES ("샌_점보4단햄치킨",2500,100,"instant");
# INSERT INTO Item_info (Product_name, Price, Qty, Category) VALUES ("햄_크림치즈치킨버거",3300,100,"instant");
# INSERT INTO Item_info (Product_name, Price, Qty, Category) VALUES ("햄_빽햄롱롱버거",2900,100,"instant");
# INSERT INTO Item_info (Product_name, Price, Qty, Category) VALUES ("주_빽햄데리마요밥바",1900,100,"instant");
# INSERT INTO Item_info (Product_name, Price, Qty, Category) VALUES ("주_2XL콘햄김치볶음밥",1400,100,"instant");
# INSERT INTO Item_info (Product_name, Price, Qty, Category) VALUES ("주_2XL소불고기",1400,100,"instant");
# INSERT INTO Item_info (Product_name, Price, Qty, Category) VALUES ("도_빽햄스페셜정식",4300,100,"instant");
# INSERT INTO Item_info (Product_name, Price, Qty, Category) VALUES ("햄_미트칠리더블버거",2800,100,"instant");
# INSERT INTO Item_info (Product_name, Price, Qty, Category) VALUES ("햄_햄에그샐러드버거",2700,100,"instant");
# ...

# %%
mydb.commit()
