# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv('apriori_data1.csv',header=None)
df1
# Out:
#                       0               1                 2              3   \
# 0                   pork   sandwich bags        lunch meat   all- purpose
# 1                shampoo       hand soap           waffles     vegetables
# 2                   pork            soap         ice cream   toilet paper
# 3                  juice      lunch meat              soda   toilet paper
# 4                  pasta       tortillas             mixes      hand soap
# ...                  ...             ...               ...            ...
# 1494                beef   sandwich bags         hand soap   paper towels
# 1495        dinner rolls      lunch meat   spaghetti sauce          pasta
# 1496          lunch meat            eggs           poultry     vegetables
# 1497             ketchup            milk           poultry        cheeses
# 1498   laundry detergent      vegetables           shampoo     vegetables
#
#                  4              5                 6                  7   \
# ...

# %%
df2=pd.read_csv('apriori_data2.csv')
df2.columns=np.array(range(len(df2.columns)))
df2
# Out:
#                        0                    1                 2   \
# 0            citrus fruit  semi-finished bread         margarine
# 1          tropical fruit               yogurt            coffee
# 2              whole milk                  NaN               NaN
# 3               pip fruit               yogurt      cream cheese
# 4        other vegetables           whole milk    condensed milk
# ...                   ...                  ...               ...
# 9830              sausage              chicken              beef
# 9831    cooking chocolate                  NaN               NaN
# 9832              chicken         citrus fruit  other vegetables
# 9833  semi-finished bread        bottled water              soda
# 9834              chicken       tropical fruit  other vegetables
#
#                             3              4               5   \
# 0                  ready soups            NaN             NaN
# ...

# %%
df=pd.concat([df1,df2])
df.set_index(np.array(range(len(df))),inplace=True)
df
# Out:
#                         0               1                 2               3   \
# 0                     pork   sandwich bags        lunch meat    all- purpose
# 1                  shampoo       hand soap           waffles      vegetables
# 2                     pork            soap         ice cream    toilet paper
# 3                    juice      lunch meat              soda    toilet paper
# 4                    pasta       tortillas             mixes       hand soap
# ...                    ...             ...               ...             ...
# 11329              sausage         chicken              beef  hamburger meat
# 11330    cooking chocolate             NaN               NaN             NaN
# 11331              chicken    citrus fruit  other vegetables          butter
# 11332  semi-finished bread   bottled water              soda    bottled beer
# 11333              chicken  tropical fruit  other vegetables         vinegar
#
# ...

# %%
for i in range(len(df.columns)):
    df[i]=df[i].str.strip()
df
# Out:
#                         0               1                 2               3   \
# 0                     pork   sandwich bags        lunch meat    all- purpose
# 1                  shampoo       hand soap           waffles      vegetables
# 2                     pork            soap         ice cream    toilet paper
# 3                    juice      lunch meat              soda    toilet paper
# 4                    pasta       tortillas             mixes       hand soap
# ...                    ...             ...               ...             ...
# 11329              sausage         chicken              beef  hamburger meat
# 11330    cooking chocolate             NaN               NaN             NaN
# 11331              chicken    citrus fruit  other vegetables          butter
# 11332  semi-finished bread   bottled water              soda    bottled beer
# 11333              chicken  tropical fruit  other vegetables         vinegar
#
# ...

# %%
prod_list=set(df.values.ravel().tolist())
prod_list
# Out:
# {'',
#  'Instant food products',
#  'UHT-milk',
#  'abrasive cleaner',
#  'all- purpose',
#  'aluminum foil',
#  'artif. sweetener',
#  'baby cosmetics',
#  'baby food',
#  'bagels',
#  'bags',
#  'baking powder',
#  'bathroom cleaner',
#  'beef',
#  'berries',
#  'beverages',
#  'bottled beer',
#  'bottled water',
#  'brandy',
#  'brown bread',
#  'butter',
#  'butter milk',
#  'cake bar',
#  'candles',
#  'candy',
#  'canned beer',
#  'canned fish',
#  'canned fruit',
#  'canned vegetables',
#  'cat food',
#  'cereals',
#  'cheeses',
#  'chewing gum',
#  'chicken',
#  'chocolate',
#  'chocolate marshmallow',
#  'citrus fruit',
#  'cleaner',
#  'cling film/bags',
#  'cocoa drinks',
#  'coffee',
#  'coffee/tea',
#  'condensed milk',
#  'cooking chocolate',
#  'cookware',
#  'cream',
#  'cream cheese',
#  'curd',
#  'curd cheese',
#  'decalcifier',
#  'dental care',
#  'dessert',
#  'detergent',
#  'dinner rolls',
#  'dish cleaner',
#  'dishes',
#  'dishwashing liquid/detergent',
# ...

# %%
drop_list=['',np.nan,
 'all- purpose',
 'aluminum foil',
 'dishwashing liquid/detergent',
 'hand soap',
 'ketchup',
 'laundry detergent',
 'mixes',
 'paper towels',
 'andwich bags',
 'shampoo',
 'soap',
 'toilet paper',
 'abrasive cleaner',
 'baby cosmetics',
 'bags',
 'baking powder',
 'bathroom cleaner',
 'bottled beer',
 'brandy',
 'candles',
 'canned beer',
 'cat food',
 'cleaner',
 'cling film/bags',
 'cookware',
 'curd',
 'decalcifier',
 'dental care',
 'detergent',
 'dish cleaner',
 'dishes',
 'dog food',
 'female sanitary products',
 'finished products',
 'flower (seeds)',
 'flower soil/fertilizer',
 'frankfurter',
 'hair spray',
 'herbs',
 'house keeping products',
 'hygiene articles',
 'ketchup',
 'kitchen towels',
 'kitchen utensil',
 'light bulbs',
 'liqueur',
 'liquor',
 'liquor (appetizer)',
 'liver loaf',
 'make up remover',
 'male cosmetics',
 'margarine',
 'mayonnaise',
 'napkins',
 'newspapers',
 'pet care',
 'photo/film',
 'pickled vegetables',
 'potted plants',
 'preservation products',
 'prosecco',
 'red/blush wine',
 'rubbing alcohol',
 'rum',
 'seasonal products',
 'shopping bags',
 'skin care',
 'soap',
 'softener',
 'sound storage medium',
 'sparkling wine',
 'specialty bar',
 'specialty fat',
 'syrup',
 'toilet cleaner',
 'turkey',
 'vinegar',
 'whisky',
 'white wine']

# %%
real_list=set(prod_list)-set(drop_list)
print(len(real_list))
real_list
# Out:
# 118
# {'Instant food products',
#  'UHT-milk',
#  'artif. sweetener',
#  'baby food',
#  'bagels',
#  'beef',
#  'berries',
#  'beverages',
#  'bottled water',
#  'brown bread',
#  'butter',
#  'butter milk',
#  'cake bar',
#  'candy',
#  'canned fish',
#  'canned fruit',
#  'canned vegetables',
#  'cereals',
#  'cheeses',
#  'chewing gum',
#  'chicken',
#  'chocolate',
#  'chocolate marshmallow',
#  'citrus fruit',
#  'cocoa drinks',
#  'coffee',
#  'coffee/tea',
#  'condensed milk',
#  'cooking chocolate',
#  'cream',
#  'cream cheese',
#  'curd cheese',
#  'dessert',
#  'dinner rolls',
#  'domestic eggs',
#  'eggs',
#  'fish',
#  'flour',
#  'frozen chicken',
#  'frozen dessert',
#  'frozen fish',
#  'frozen fruits',
#  'frozen meals',
#  'frozen potato products',
#  'frozen vegetables',
#  'fruit/vegetable juice',
#  'fruits',
#  'grapes',
#  'ham',
#  'hamburger meat',
#  'hard cheese',
#  'honey',
#  'ice cream',
#  'individual meals',
#  'instant coffee',
#  'jam',
# ...

# %%
for i in drop_list:
    df.replace(i,np.nan,inplace=True)
df
# Out:
#                         0               1                 2               3   \
# 0                     pork   sandwich bags        lunch meat             NaN
# 1                      NaN             NaN           waffles      vegetables
# 2                     pork             NaN         ice cream             NaN
# 3                    juice      lunch meat              soda             NaN
# 4                    pasta       tortillas               NaN             NaN
# ...                    ...             ...               ...             ...
# 11329              sausage         chicken              beef  hamburger meat
# 11330    cooking chocolate             NaN               NaN             NaN
# 11331              chicken    citrus fruit  other vegetables          butter
# 11332  semi-finished bread   bottled water              soda             NaN
# 11333              chicken  tropical fruit  other vegetables             NaN
#
# ...

# %%
df.to_csv('apriori_data.csv')
